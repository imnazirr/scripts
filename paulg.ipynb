# %%
import requests
from bs4 import BeautifulSoup
import csv

def fetch_articles(url):
    try:
        # Send a request to fetch the HTML content
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for HTTP errors

        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find all the article links
        article_links = soup.find_all('a')

        # Extract the titles and links
        articles = []
        for link in article_links:
            title = link.get_text()
            href = link.get('href')
            if href and href.endswith('.html'):
                if href.startswith('http'):
                    article_url = href
                else:
                    article_url = f'http://www.paulgraham.com/{href}'
                
                articles.append({'title': title, 'url': article_url})

        return articles
    except requests.RequestException as e:
        print(f"Error fetching the articles: {e}")
        return []

def save_articles_to_csv(articles, filename):
    try:
        # Define the CSV file headers
        headers = ['Title', 'URL']

        # Open the CSV file for writing
        with open(filename, mode='w', newline='', encoding='utf-8') as file:
            writer = csv.DictWriter(file, fieldnames=headers)
            
            # Write the header
            writer.writeheader()
            
            # Write the article data
            for article in articles:
                writer.writerow(article)
        
        print(f"Articles successfully saved to {filename}")
    except Exception as e:
        print(f"Error saving to CSV: {e}")

def main():
    url = 'http://www.paulgraham.com/articles.html'
    articles = fetch_articles(url)
    if articles:
        save_articles_to_csv(articles, 'paul_graham_articles.csv')

if __name__ == "__main__":
    main()
# Out:
# Error saving to CSV: dict contains fields not in fieldnames: 'url', 'title'

# %%
import requests
from bs4 import BeautifulSoup
import csv

def fetch_articles(url):
    try:
        # Send a request to fetch the HTML content
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for HTTP errors

        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find all the article links
        article_links = soup.find_all('a')

        # Extract the titles and links
        articles = []
        for link in article_links:
            title = link.get_text()
            href = link.get('href')
            if href and href.endswith('.html'):
                if href.startswith('http'):
                    article_url = href
                else:
                    article_url = f'http://www.paulgraham.com/{href}'
                
                articles.append({'Title': title, 'URL': article_url})

        return articles
    except requests.RequestException as e:
        print(f"Error fetching the articles: {e}")
        return []

def save_articles_to_csv(articles, filename):
    try:
        # Define the CSV file headers
        headers = ['Title', 'URL']

        # Open the CSV file for writing
        with open(filename, mode='w', newline='', encoding='utf-8') as file:
            writer = csv.DictWriter(file, fieldnames=headers)
            
            # Write the header
            writer.writeheader()
            
            # Write the article data
            for article in articles:
                writer.writerow(article)
        
        print(f"Articles successfully saved to {filename}")
    except Exception as e:
        print(f"Error saving to CSV: {e}")

def main():
    url = 'http://www.paulgraham.com/articles.html'
    articles = fetch_articles(url)
    if articles:
        save_articles_to_csv(articles, 'paul_graham_articles.csv')

if __name__ == "__main__":
    main()
# Out:
# Articles successfully saved to paul_graham_articles.csv

# %%
import requests
from bs4 import BeautifulSoup
import csv

def fetch_articles(url):
    try:
        # Send a request to fetch the HTML content
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for HTTP errors

        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find all the article links
        article_links = soup.find_all('a')

        # Extract the titles and links
        articles = []
        for link in article_links:
            title = link.get_text()
            href = link.get('href')
            if href and href.endswith('.html'):
                if href.startswith('http'):
                    article_url = href
                else:
                    article_url = f'http://www.paulgraham.com/{href}'
                
                content = fetch_essay_content(article_url)
                articles.append({'Title': title, 'URL': article_url, 'Content': content})

        return articles
    except requests.RequestException as e:
        print(f"Error fetching the articles: {e}")
        return []

def fetch_essay_content(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Assuming the content of the essay is within <p> tags
        paragraphs = soup.find_all('p')
        content = "\n".join([para.get_text() for para in paragraphs])
        return content
    except requests.RequestException as e:
        print(f"Error fetching the content from {url}: {e}")
        return ""

def save_articles_to_csv(articles, filename):
    try:
        # Define the CSV file headers
        headers = ['Title', 'URL', 'Content']

        # Open the CSV file for writing
        with open(filename, mode='w', newline='', encoding='utf-8') as file:
            writer = csv.DictWriter(file, fieldnames=headers)
            
            # Write the header
            writer.writeheader()
            
            # Write the article data
            for article in articles:
                writer.writerow(article)
        
        print(f"Articles successfully saved to {filename}")
    except Exception as e:
        print(f"Error saving to CSV: {e}")

def main():
    url = 'http://www.paulgraham.com/articles.html'
    articles = fetch_articles(url)
    if articles:
        save_articles_to_csv(articles, 'paul_graham_articles.csv')

if __name__ == "__main__":
    main()
# Out:
# Articles successfully saved to paul_graham_articles.csv
